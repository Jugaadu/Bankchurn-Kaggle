# %%
import pandas as pd
import numpy as np

# %%
path = './'

# %%
data_train = pd.read_csv("train.csv", index_col = "id")
data_test = pd.read_csv("test.csv",index_col = "id")

# %%
# data.head()

# %%
data_train["Exited"].value_counts()/len(data.index)
# Out:
# Exited
# 0    0.788401
# 1    0.211599
# Name: count, dtype: float64

# %%
data_train.describe()
# Out:
#          CustomerId    CreditScore            Age         Tenure  \
# count  1.650340e+05  165034.000000  165034.000000  165034.000000
# mean   1.569201e+07     656.454373      38.125888       5.020353
# std    7.139782e+04      80.103340       8.867205       2.806159
# min    1.556570e+07     350.000000      18.000000       0.000000
# 25%    1.563314e+07     597.000000      32.000000       3.000000
# 50%    1.569017e+07     659.000000      37.000000       5.000000
# 75%    1.575682e+07     710.000000      42.000000       7.000000
# max    1.581569e+07     850.000000      92.000000      10.000000
#
#              Balance  NumOfProducts      HasCrCard  IsActiveMember  \
# count  165034.000000  165034.000000  165034.000000   165034.000000
# mean    55478.086689       1.554455       0.753954        0.497770
# std     62817.663278       0.547154       0.430707        0.499997
# min         0.000000       1.000000       0.000000        0.000000
# ...

# %%
data_train.columns
# Out:
# Index(['CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age',
#        'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
y = data_train["Exited"]
X = data_train.drop(["Exited"], axis = 1)

# %%
features = ['CreditScore', 'Geography', 'Gender', 'Age','Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember','EstimatedSalary']

X = data_train[features]
test_X = data_test[features]
X.head()
# Out:
#     CreditScore Geography Gender   Age  Tenure    Balance  NumOfProducts  \
# id
# 0           668    France   Male  33.0       3       0.00              2
# 1           627    France   Male  33.0       1       0.00              2
# 2           678    France   Male  40.0      10       0.00              2
# 3           581    France   Male  34.0       2  148882.54              1
# 4           716     Spain   Male  33.0       5       0.00              2
#
#     HasCrCard  IsActiveMember  EstimatedSalary
# id
# 0         1.0             0.0        181449.97
# 1         1.0             1.0         49503.50
# 2         1.0             0.0        184866.69
# 3         1.0             1.0         84560.88
# 4         1.0             1.0         15068.83

# %%
# create a validation set to validate model outcome
from sklearn.model_selection import train_test_split
train_X, val_X, train_y, val_y = train_test_split(X, y,random_state = 1)

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()
cat_var = [ 'Geography', 'Gender']

ohe = OneHotEncoder()
data = ohe.fit_transform(X)
df1 = pd.DataFrame(data.toarray(), columns=ohe.get_feature_names_out(), dtype=int)
# for feat in cat_var:
#     X[feat] = ohe.fit_transform(X[feat])
#     test_X[feat] = ohe.transform(test_X[feat])

# %%
le = LabelEncoder()

# %%
cat_var = [ 'Geography', 'Gender']

for feat in cat_var:
    X[feat] = le.fit_transform(X[feat].astype(str) + )
# Out:
# /var/folders/12/1tc9bjjs47scy6vmc0dylfnr0000gn/T/ipykernel_43965/3665563826.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[feat] = le.fit_transform(X[feat].astype(str))
# /var/folders/12/1tc9bjjs47scy6vmc0dylfnr0000gn/T/ipykernel_43965/3665563826.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[feat] = le.fit_transform(X[feat].astype(str))

# %%
X.head()
# Out:
#     CreditScore  Geography  Gender   Age  Tenure    Balance  NumOfProducts  \
# id
# 0           668          0       1  33.0       3       0.00              2
# 1           627          0       1  33.0       1       0.00              2
# 2           678          0       1  40.0      10       0.00              2
# 3           581          0       1  34.0       2  148882.54              1
# 4           716          2       1  33.0       5       0.00              2
#
#     HasCrCard  IsActiveMember  EstimatedSalary
# id
# 0         1.0             0.0        181449.97
# 1         1.0             1.0         49503.50
# 2         1.0             0.0        184866.69
# 3         1.0             1.0         84560.88
# 4         1.0             1.0         15068.83

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(random_state = 1)

# %%
model.fit(X,y)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
predict = model.predict(X)

# %%
predict[:5]
# Out:
# array([0, 0, 0, 0, 0])

# %%
y.head()
# Out:
# id
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %%
test = pd.read_csv("test.csv", index_col = "id")

# %%
test = test[features]

# %%
for f in cat_var:
    test[f] = le.transform(test[f])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_encode.py:225, in _encode(values, uniques, check_unknown)
#     224 try:
# --> 225     return _map_to_integer(values, uniques)
#     226 except KeyError as e:
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_encode.py:165, in _map_to_integer(values, uniques)
#     164 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 165 return np.array([table[v] for v in values])
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_encode.py:165, in <listcomp>(.0)
#     164 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 165 return np.array([table[v] for v in values])
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_encode.py:159, in _nandict.__missing__(self, key)
# ...
